# %%
import numpy as np
import matplotlib.pyplot as plt
import urllib.request
import pandas as pd

#definindo gaussiana

Lambdas=np.linspace(380,780,400)

def gauss(x, amp, mu, sigma):
    return amp * np.exp(-0.5 * ((x - mu) / sigma)**2)

x_barra=gauss(Lambdas,10,450,10)
x_barra=gauss(Lambdas,10,450,10)x_barra=gauss(Lambdas,10,450,10)
# ==========================================
# 3. PLOTANDO TUDO JUNTO
# ==========================================
plt.figure(figsize=(12, 6))


# 1. Plotando o Seu Modelo Analítico (Gaussianas)
plt.plot(Lambdas, x_barra, label='HbO2 (Seu Modelo)', color='red', linewidth=2)
plt.plot(Lambdas, y_barra, label='Hb (Seu Modelo)', color='green', linestyle='--', linewidth=2)
plt.plot(Lambdas, z_barra, label='HbO2 (Seu Modelo)', color='blue', linewidth=2)

plt.title('Ajuste Analítico (Gaussianas) vs Dados Reais (OMLC)', fontsize=14)
plt.xlabel('Comprimento de Onda (nm)', fontsize=12)
plt.ylabel(r'Coeficiente de Absorção $\mu_a$ ($mm^{-1}$)', fontsize=12)

# Usando escala logarítmica para enxergar os picos secundários
plt.yscale('log')
plt.ylim(bottom=0.1,top=150) 

plt.grid(True, which="both", ls="--", alpha=0.4)
plt.legend()
plt.show()
